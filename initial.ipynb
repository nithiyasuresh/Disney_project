# %%
import pandas as pd

# %%
# disney_movies_df = pd.read_csv("./data/disney_movies_total_gross.csv")

# %%
# disney_movies_df.info()

# %%
# disney_movies_df

# %%
disney_plus_shows_df = pd.read_csv("./data/disney_plus_shows.csv")
disney_plus_shows_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdb_id      894 non-null    object
#  1   title        894 non-null    object
#  2   plot         866 non-null    object
#  3   type         894 non-null    object
#  4   rated        742 non-null    object
#  5   year         894 non-null    object
#  6   released_at  874 non-null    object
#  7   added_at     992 non-null    object
#  8   runtime      838 non-null    object
#  9   genre        885 non-null    object
#  10  director     689 non-null    object
#  11  writer       743 non-null    object
#  12  actors       870 non-null    object
#  13  language     865 non-null    object
#  14  country      869 non-null    object
#  15  awards       556 non-null    object
#  16  metascore    292 non-null    float64
#  17  imdb_rating  879 non-null    float64
# ...

# %%
disney_plus_shows_df
# Out:
#        imdb_id                                       title  \
# 0    tt0147800                  10 Things I Hate About You
# 1    tt7019028                        101 Dalmatian Street
# 2    tt0115433                              101 Dalmatians
# 3    tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4    tt0211181                              102 Dalmatians
# ..         ...                                         ...
# 987  tt3544734                                      Zapped
# 988  tt0186726             Zenon: Girl of the 21st Century
# 989  tt0271271                           Zenon: The Zequel
# 990  tt0379060                                   Zenon: Z3
# 991  tt2948356                                    Zootopia
#
#                                                   plot    type  rated   year  \
# 0    A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1    This series follows the lives of Delilah and D...  series    NaN  2018–
# ...

# %%
disney_plus_shows_df.columns
# Out:
# Index(['imdb_id', 'title', 'plot', 'type', 'rated', 'year', 'released_at',
#        'added_at', 'runtime', 'genre', 'director', 'writer', 'actors',
#        'language', 'country', 'awards', 'metascore', 'imdb_rating',
#        'imdb_votes'],
#       dtype='object')

# %%
# Removing unwanted columns
disney_plus_shows_df.drop(columns=['imdb_id','title','plot','rated','released_at','added_at','genre', 'director', 'writer', 'actors','language', 'country', 'awards', 'metascore','imdb_votes'], inplace=True)
disney_plus_shows_df
# Out:
#        type   year  runtime  imdb_rating
# 0     movie   1999   97 min          7.3
# 1    series  2018–      NaN          6.2
# 2     movie   1996  103 min          5.7
# 3     movie   2002   74 min          5.8
# 4     movie   2000  100 min          4.9
# ..      ...    ...      ...          ...
# 987   movie   2014  102 min          5.1
# 988   movie   1999   97 min          6.4
# 989   movie   2001  100 min          5.9
# 990   movie   2004   81 min          5.5
# 991   movie   2016  108 min          8.0
#
# [992 rows x 4 columns]

# %%
disney_plus_shows_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   type         894 non-null    object
#  1   year         894 non-null    object
#  2   runtime      838 non-null    object
#  3   imdb_rating  879 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 31.1+ KB

# %%
# Dropping nan values from the dataframe

disney_plus_shows_df.dropna(axis='rows', how='any', inplace=True)
disney_plus_shows_df
# Out:
#       type  year  runtime  imdb_rating
# 0    movie  1999   97 min          7.3
# 2    movie  1996  103 min          5.7
# 3    movie  2002   74 min          5.8
# 4    movie  2000  100 min          4.9
# 5    movie  2011   90 min          6.3
# ..     ...   ...      ...          ...
# 987  movie  2014  102 min          5.1
# 988  movie  1999   97 min          6.4
# 989  movie  2001  100 min          5.9
# 990  movie  2004   81 min          5.5
# 991  movie  2016  108 min          8.0
#
# [831 rows x 4 columns]

# %%
# Identify the target variable as metascore
y = disney_plus_shows_df['imdb_rating']
y
# Out:
# 0      7.3
# 2      5.7
# 3      5.8
# 4      4.9
# 5      6.3
#       ...
# 987    5.1
# 988    6.4
# 989    5.9
# 990    5.5
# 991    8.0
# Name: imdb_rating, Length: 831, dtype: float64

# %%
X = disney_plus_shows_df.drop(columns=['imdb_rating'])
X
# Out:
#       type  year  runtime
# 0    movie  1999   97 min
# 2    movie  1996  103 min
# 3    movie  2002   74 min
# 4    movie  2000  100 min
# 5    movie  2011   90 min
# ..     ...   ...      ...
# 987  movie  2014  102 min
# 988  movie  1999   97 min
# 989  movie  2001  100 min
# 990  movie  2004   81 min
# 991  movie  2016  108 min
#
# [831 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# simple regression
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
# Fitting our model with all of our features in X
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-fd0a76a06971> in <module>
#       1 # Fitting our model with all of our features in X
# ----> 2 model.fit(X_train, y_train)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# ...

# %%
# predict y
y_predict = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-22-ef80f69c3772> in <module>
#       1 # predict y
# ----> 2 y_predict = model.predict(X_test)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     214
#     215     def _decision_function(self, X):
# --> 216         check_is_fitted(self)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ...

# %%
# access the model
score = model.score(y_test, prediction)
